# %%
from receiver_side import rxBasicSettings, receiver
from transmitter_side import transmitter, txBasicSettings
from validation import sendMultiplePackets

# %%
txBasicSettings(False)
rxBasicSettings()

# %%
txData = input("Enter text: ")
txPacket = transmitter(txData)

# %%
rxData = receiver()[0]
print("Message:", rxData)

# %%
ber, packetError = sendMultiplePackets(10)
print("Percent of correctly transmitted packets: ")
print (packetError)
print("Bit Error Rate: ")
print(ber)
# Out:
# True
# True
# No reliable preamble lock.
# False
# No reliable preamble lock.
# False
# True
# True
# No reliable preamble lock.
# False
# True
# True
# True
# Percent of correctly transmitted packets:
# 90.0
# Bit Rate Error:
# 58.203125
