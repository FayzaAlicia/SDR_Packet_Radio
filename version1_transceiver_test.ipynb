# %%
from receiver_side import receiver
from transmitter_side import transmitter
import adi

# %%
txData = input("Enter text: ")
txPacket = transmitter(txData)

# %%
sdr = adi.ad9361()
data_rx = sdr.rx()

# %%
#rxData = receiver(txPacket)
rxData = receiver(data_rx)
print("Message:", rxData)
